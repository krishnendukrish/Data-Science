# %%
from sklearn.datasets import load_iris
x,y=load_iris(return_X_y=True)
x=x[:,0:2]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
c=LinearRegression()
c.fit(xtrain,ytrain)
p=c.predict(xtest)
print("Actual values")
print(ytest)
print("Predicted values")
print(p)
# Out:
# Actual values
# [2 1 0 2 0 2 0 1 1 1 2 1 1 1 1 0 1 1 0 0 2 1 0 0 2 0 0 1 1 0 2 1 0 2 2 1 0
#  1]
# Predicted values
# [ 1.12886370e+00  1.65609770e+00  2.38453029e-02  2.19277865e+00
#   1.50930332e-01  1.19027911e+00  8.80968527e-02  1.61641232e+00
#   1.88002932e+00  1.35421339e+00  1.47988035e+00  1.32822915e+00
#   1.35421339e+00  1.65467963e+00  1.29137991e+00 -4.98531886e-02
#   1.21626335e+00  1.02918098e+00  2.52031128e-01  1.37229180e-01
#   9.78630580e-01  8.52963621e-01  6.97209116e-04  1.43983611e-02
#   1.42932995e+00 -2.75202874e-01 -2.52870248e-02  1.36649647e+00
#   8.42098609e-01  1.50930332e-01  1.39106263e+00  7.02730498e-01
#   2.38329976e-01  1.22854643e+00  1.57956307e+00  7.40997813e-01
#   4.25412345e-01  1.34193031e+00]

# %%
from sklearn.metrics import r2_score,mean_squared_error
print("r2_score")
r2=r2_score(ytest,p)
print(r2)
# Out:
# r2_score
# 0.6457291807728918

# %%
print("mean_squared_error")
mean=mean_squared_error(ytest,p)
print(mean)
# Out:
# mean_squared_error
# 0.20117872005971515

# %%
print("Intercept")
print(c.intercept_)
# Out:
# Intercept
# -1.4685594392713053

# %%
print("Coefficient")
print(c.coef_)
# Out:
# Coefficient
# [ 0.75116562 -0.6283348 ]

# %%
import matplotlib.pyplot as plt
print("Graphical representation of Multiple linear regression")
plt.scatter(xtest[:,0],ytest)
plt.plot(xtest[:,0],p,color="green")
plt.title("Actual v/s Predicted")
plt.show()
# Out:
# Graphical representation of Multiple linear regression
